# %%
import numpy as np
import matplotlib.pyplot as plt

from skimage.data import shepp_logan_phantom
from skimage.transform import radon, iradon, rescale

from IPython.display import display, clear_output

# %%
image = shepp_logan_phantom()
theta = np.linspace(0., 180., max(image.shape), endpoint=False)
sinogram = radon(image, theta=theta)
fb = iradon(sinogram, filter_name="ramp")

plt.figure(figsize=(10, 10))

plt.subplot(221)
plt.imshow(image, cmap='gray')

plt.subplot(222)
plt.imshow(sinogram, cmap='gray')

plt.subplot(223)
plt.imshow(fb, cmap='gray')

plt.subplot(224)
plt.imshow(image - fb, cmap='gray')
plt.show()

# %%
sinogram = np.loadtxt("phantom1.txt", dtype=np.float32)
sinogram = sinogram.transpose()
phantom1_sig = iradon(sinogram, theta=np.linspace(0., 360., 100, endpoint=False), filter_name="ramp", circle=False)
phantom1_sig.shape, phantom1_sig.dtype
# Out:
# ((71, 71), dtype('float32'))

# %%
plt.figure(figsize=(15, 15))

plt.subplot(121)
plt.imshow(phantom1_sig, cmap='gray')

plt.subplot(122)
plt.imshow(sinogram, cmap='gray')
